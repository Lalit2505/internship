# %%
# importing libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# importing selenium webdriver
from selenium import webdriver

# importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# Importing requests
import requests

#import regex
import requests
from selenium.webdriver.common.by import By

import time

# %%
driver=webdriver.Chrome(r"D:\chromedriver_winn.exe")
# Out:
# C:\Users\Lalit Sharnagat\AppData\Local\Temp\ipykernel_9724\3232580153.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"D:\chromedriver_winn.exe")

# %% [markdown]
# # Question No:-1&2

# %%
driver.get('https://www.amazon.in/')

# %%
search_field_designation=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
search_field_designation.send_keys(input("enter the user input:-"))
# Out:
# enter the user input:-guitar

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
product_url=[]
start=0
end=3
for page in range(start,end):    
    url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        product_url.append(i.get_attribute('href'))
        print(i.get_attribute('href'))
    next_button=driver.find_element(By.XPATH,'//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    next_button.click()
    time.sleep(3)
# Out:
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo3OTg1NTA3NjcwNjA3NDMzOjE2NzgzOTIyOTk6c3BfYXRmOjIwMTIxNzg0MjQwOTk4OjowOjo&url=%2FKadence-Frontier-Acoustic-Guitar-Equalizer%2Fdp%2FB01HRIHJWY%2Fref%3Dsr_1_1_sspa%3Fcrid%3DOS4J3NCE502%26keywords%3Dguitar%26qid%3D1678392299%26sprefix%3Dguitar%252Caps%252C1374%26sr%3D8-1-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1
# https://www.amazon.in/sspa/click?ie=UTF8&spc=MTo3OTg1NTA3NjcwNjA3NDMzOjE2NzgzOTIyOTk6c3BfYXRmOjIwMDk2NjA4NzUwNDk4OjowOjo&url=%2FKadence-Frontier-Acoustic-Guitar-Strings%2Fdp%2FB01GDZ46AA%2Fref%3Dsr_1_2_sspa%3Fcrid%3DOS4J3NCE502%26keywords%3Dguitar%26qid%3D1678392299%26sprefix%3Dguitar%252Caps%252C1374%26sr%3D8-2-spons%26sp_csd%3Dd2lkZ2V0TmFtZT1zcF9hdGY%26psc%3D1%26smid%3DAM04Z7MH4HSDD
# ...

# %%
print(len(product_url))
# Out:
# 199

# %%
Name_of_product=[]
Price=[]
Return_Exchange=[]
Expected_Delivery=[]
Availability=[]

# %%
for url in product_url[0:100]:
    driver.get(url)
    time.sleep(5)
    
    try:
        name_of_product=driver.find_element(By.XPATH,'//span[@class="a-size-large product-title-word-break"]')
        Name_of_product.append(name_of_product.text)
    except NoSuchElementException:
        Name_of_product.append('-')
        
    try:
        price=driver.find_element(By.XPATH,'//span[@class="a-price-whole"]')
        Price.append(price.text)
    except NoSuchElementException :
        Price.append('-')
    
    try:
        expected_Delivery=driver.find_element(By.XPATH,'//span[@class="a-text-bold"]')
        Expected_Delivery.append(expected_Delivery.text)
    except NoSuchElementException :
        Expected_Delivery.append('-')
        
    try:
        availability=driver.find_element(By.XPATH,'//span[@class="a-size-medium a-color-success"]')
        Availability.append(availability.text)
    except NoSuchElementException :
        Availability.append('-')
    
    try:
        return_Exchange=driver.find_element(By.XPATH,'//span[@class="a-declarative"]/div/a')
        Return_Exchange.append(return_Exchange.text)
    except NoSuchElementException :
        Return_Exchange.append('-')

# %%
print(len(Name_of_product),len(Price),len(Return_Exchange),len(Expected_Delivery),len(Availability))
# Out:
# 100 100 100 100 100

# %%
import pandas as pd
df=pd.DataFrame({'Name of product':Name_of_product[0:100],'Prices':Price[0:100],'Return Exchange':Return_Exchange[0:100],'Expected Delivery':Expected_Delivery[0:100],'Available':Availability[0:100],'Product url':product_url[0:100]})
df
# Out:
#                                       Name of product  Prices  \
# 0   Kadence Frontier Jumbo Semi Acoustic Guitar Wi...   6,499
# 1   Kadence Frontier guitar with Online Guitar lea...   5,008
# 2   Fender Acoustic Guitar Dreadnought Solid CD60S...  13,340
# 3   INTERN 41 inches Acoustic Guitar with truss ro...   4,051
# 4   Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...   1,899
# ..                                                ...     ...
# 95  Juârez JRZ38C/MAH 6 Strings Acoustic Guitar 38...   3,461
# 96  Kadence Frontier 34inch guitar for Kids, Trave...   3,899
# 97  Juârez JRZ38C/WH 6 Strings Acoustic Guitar 38 ...   3,321
# 98  Yamaha FX280 Tobacco Brown Sunburst Electro Ac...  10,956
# 99  ORANGEWOOD OLIVER JR. MAHOGANY MINI GRAND CONC...  20,576
#
#        Return Exchange    Expected Delivery Available  \
# 0   7 days Replacement    Tuesday, 14 March  In stock
# 1   7 days Replacement     Monday, 13 March  In stock
# 2   7 days Replacement                              -
# ...

# %%
driver.get('https://www.google.com')

# %%
designation=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input")
designation.send_keys("images.google.com")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[2]/div[2]/div[5]/center/input[1]")
search.click()

# %%
imagesearch=driver.find_element(By.XPATH,"/html/body/div[7]/div/div[11]/div/div[2]/div[2]/div/div/div[1]/div/div/div[1]/div/a/div/div/div/cite")
imagesearch.click()

# %%
imagedesignation=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input")
imagedesignation.send_keys("cake")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button")
search.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,100)")
    
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]') 

img_url=[]
img_data=[]

for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            img_url.append(source)
            
for i in range(len(img_url)):
    if i > 10:
        break
        print("Downloading {0} of {8} images".format(i,8))
        response=requests.get(img_url[i])
        file=open(r"D:\filiprobo"+str(i)+".jpg","wb")
        file.write(response.content)

# %%
print(len(img_url))
# Out:
# 248

# %% [markdown]
# # Question No:-4

# %%
driver.get('https://www.flipkart.com/')

# %%
search_field_designation=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
search_field_designation.send_keys("Oneplus Nord ")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search.click()

# %%
product_url=[] 
url=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in url:
    product_url.append(i.get_attribute('href'))
    print(i.get_attribute('href'))
    time.sleep(3)
# Out:
# https://www.flipkart.com/oneplus-nord-ce-2-lite-5g-black-dusk-128-gb/p/itm537fc2aa73747?pid=MOBGHBZHB7YJT5HF&lid=LSTMOBGHBZHB7YJT5HFKTSMW7&marketplace=FLIPKART&q=Oneplus+Nord+&store=tyy%2F4io&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=f768c3cf-1087-46d8-8b90-134b5114d83d.MOBGHBZHB7YJT5HF.SEARCH&ppt=hp&ppn=homepage&ssid=m1unuupzvk0000001678736140108&qH=e4b4d41bcbe34390
# https://www.flipkart.com/oneplus-nord-ce-2-lite-5g-blue-tide-128-gb/p/itm7acae55b999e6?pid=MOBGHBNGY5NDH3GV&lid=LSTMOBGHBNGY5NDH3GVAIZDNM&marketplace=FLIPKART&q=Oneplus+Nord+&store=tyy%2F4io&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=f768c3cf-1087-46d8-8b90-134b5114d83d.MOBGHBNGY5NDH3GV.SEARCH&ppt=hp&ppn=homepage&ssid=m1unuupzvk0000001678736140108&qH=e4b4d41bcbe34390
# ...

# %%
print(len(product_url))
# Out:
# 24

# %%
Brand_name=[]
Smartphone_name=[]
Colour_name=[]
Primary_camera=[]
Ram_storage=[]
Rom_storage=[]
Secondary_camera=[]
Display_size=[]
Battery_capcity=[]
Price_mobile=[]

# %%
for url in product_url:
    driver.get(url)
    time.sleep(5)
    
    try:
        brand_name=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        Brand_name.append(brand_name.text)
    except NoSuchElementException:
        Brand_name.append('-')
    
    try:
        smartphone_name=driver.find_element(By.XPATH,'//table[@class="_14cfVK"]/tbody/tr[3]/td[2]/ul/li')
        Smartphone_name.append(smartphone_name.text)
    except NoSuchElementException:
        Smartphone_name.append('-')
    
    try:
        colour_name=driver.find_element(By.XPATH,'//table[@class="_14cfVK"]/tbody/tr[4]/td[2]/ul/li')
        Colour_name.append(colour_name.text)
    except NoSuchElementException:
        Colour_name.append('-')
     
    
    
    try:
        primary_camera=driver.find_element(By.XPATH,'//div[@class="_2418kt"]/ul/li[3]')
        Primary_camera.append(primary_camera.text)
    except NoSuchElementException:
        Primary_camera.append('-')
    
    try:
        ram_storage=driver.find_element(By.XPATH,'//div[@class="_2418kt"]')
        Ram_storage.append(ram_storage.text.split('|')[0])
    except NoSuchElementException:
        Ram_storage.append('-')
     
    try:
        rom_storage=driver.find_element(By.XPATH,'//div[@class="_2418kt"]/ul/li[1]')
        Rom_storage.append(rom_storage.text.split('|')[1])
    except NoSuchElementException:
        Rom_storage.append('-')
    
    try:
        price_mobile=driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        Price_mobile.append(price_mobile.text)
    except NoSuchElementException:
        Price_mobile.append('-')
        
    try:
        display_size=driver.find_element(By.XPATH,'//div[@class="_2418kt"]/ul/li[2]')
        Display_size.append(display_size.text)
    except NoSuchElementException:
        Display_size .append('-')
        
    try:
        battery_capcity=driver.find_element(By.XPATH,'//div[@class="_2418kt"]/ul/li[4]')
        Battery_capcity.append(battery_capcity.text)
    except NoSuchElementException:
        Battery_capcity.append('-')
        
    try:
        Secondary_camera=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[6]/td[2]/ul/li')
        Secondary_camera.append(secondary_camera.text)
    except NoSuchElementException:
        Secondary_camera.append('-')

# %%
print(len(Brand_name),len(Smartphone_name),len(Colour_name),len(Primary_camera),len(Ram_storage),len(Rom_storage),len(Display_size),len(Battery_capcity),len(Price_mobile),len(product_url),len(Secondary_camera))
# Out:
# 24 24 24 24 24 24 24 24 24 24 24

# %%
import pandas as pd
df=pd.DataFrame({'Brand Name':Brand_name,'Smartphone Name':Smartphone_name,'Colour':Colour_name,'Primary Camera':Primary_camera,'Ram':Ram_storage,'Rom':Rom_storage,'Display Size':Display_size,'Battery':Battery_capcity,'price':Price_mobile,'Product url':product_url,'Secondary camera':Secondary_camera})
df
# Out:
#                                            Brand Name    Smartphone Name  \
# 0   OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...  Nord CE 2 Lite 5G
# 1   OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...  Nord CE 2 Lite 5G
# 2   OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB) ...  Nord CE 2 Lite 5G
# 3   OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...  Nord CE 2 Lite 5G
# 4   OnePlus Nord 2T 5G (Jade Fog, 128 GB)  (8 GB RAM)         Nord 2T 5G
# 5   OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...  Nord CE 2 Lite 5G
# 6   OnePlus Nord 2T 5G (Gray Shadow, 128 GB)  (8 G...         Nord 2T 5G
# 7   OnePlus Nord CE 5G (Silver Ray, 256 GB)  (12 G...         Nord CE 5G
# 8   OnePlus Nord 2T 5G (Gray Shadow, 256 GB)  (12 ...         Nord 2T 5G
# 9   OnePlus Nord CE 5G (Charcoal Ink, 128 GB)  (8 ...         Nord CE 5G
# 10  OnePlus Nord 2 5G (Gray Sierra, 128 GB)  (8 GB...          Nord 2 5G
# 11  OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)  (6...       Nord CE 2 5G
# ...

# %% [markdown]
# # Question N0:-7

# %%
driver.get('https://www.forbes.com/')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/div[1]/div/div/div")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/div[1]/div/div/div[2]/ul/li[1]/div[1]")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/div[1]/div/div/div[2]/ul/li[1]/div[2]/div[3]/ul/li[1]/a")
search.click()

# %%
Rank_title=[]
Name_title=[]
Net_worth=[]
Age_title=[]
Citizenship_title=[]
Source_title=[]
Industry_title=[]

# %%
start=0
end=5
for page in range(start,end):
    
    rank=driver.find_elements(By.XPATH,'//div[@class="rank"]')
    for i in rank:
        Rank=i.text
        Rank_title.append(Rank)
    
    name=driver.find_elements(By.XPATH,'//div[@class="personName"]')
    for i in name:
        Name=i.text
        Name_title.append(Name)

    net=driver.find_elements(By.XPATH,'//div[@class="netWorth"]')
    for i in net:
        Net=i.text
        Net_worth.append(Net)

    age=driver.find_elements(By.XPATH,'//div[@class="age"]')
    for i in age:
        Age=i.text
        Age_title.append(Age)
    
    citizenship=driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
    for i in citizenship:
        Citizenship=i.text
        Citizenship_title.append(Citizenship)
    
    source=driver.find_elements(By.XPATH,'//div[@class="source"]')
    for i in source:
        Source=i.text
        Source_title.append(Source)
    
    industry=driver.find_elements(By.XPATH,'//div[@class="source-column"]')
    for i in industry:
        Industry=i.text
        Industry_title.append(Industry)
    
    next_button=driver.find_element(By.XPATH,'//div[@class="next-page"]') 
    next_button.click()

# %%
print(len(Rank_title),len(Name_title),len(Net_worth),len(Age_title),len(Citizenship_title),len(Source_title),len(Industry_title))
# Out:
# 1000 1000 1000 1000 1000 1000 1000

# %%
import pandas as pd
df=pd.DataFrame({'Rank':Rank_title,'Name':Name_title,'Net_worth':Net_worth,'Age':Age_title,'Citizenship':Citizenship_title,'Source':Source_title,'Industry_title':Industry_title})
df
# Out:
#      Rank                      Name Net_worth Age    Citizenship  \
# 0      1.                 Elon Musk    $219 B      United States
# 1      2.                Jeff Bezos    $171 B      United States
# 2      3.  Bernard Arnault & family    $158 B             France
# 3      4.                Bill Gates    $129 B      United States
# 4      5.            Warren Buffett    $118 B      United States
# ..    ...                       ...       ...  ..            ...
# 995  984.            Harsh Mariwala    $3.1 B              India
# 996  984.               Samir Mehta    $3.1 B              India
# 997  984.              Sudhir Mehta    $3.1 B              India
# 998  984.     Pawan Munjal & family    $3.1 B              India
# 999  984.    Nguyen Thi Phuong Thao    $3.1 B            Vietnam
#
#                      Source          Industry_title
# 0             Tesla, SpaceX           Tesla, SpaceX
# 1                    Amazon                  Amazon
# ...

# %%
driver.get('https://maps.google.com')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]")
search.click()

# %%
search_field_designation=driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]")
search_field_designation.send_keys("Bhopal")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/div[1]/button")
search.click()

# %%
url_string=[]

# %%
try:
    url=driver.current_url
    url_string.append(url)
except NoSuchElementException:
    url_string.append('-')
    print("URL Extracted: ",url_string)
    lat_lng=re.findall(r'@(.*)data',url_string)
    print(lat_lng)

# %%
print(lat_lng)
# Out:
# []

# %%
url_string=driver.current_url
print("URL Extracted: ", url_string)
lat_lng=re.findall(r'@(.*)data',url_string)
# Out:
# URL Extracted:  https://www.google.com/maps/place/Bhopal,+Madhya+Pradesh/@23.1991616,77.1256977,10z/data=!3m1!4b1!4m6!3m5!1s0x397c428f8fd68fbd:0x2155716d572d4f8!8m2!3d23.2599333!4d77.412615!16zL20vMGN3NTE
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24960\2281690895.py in <module>
#       1 url_string=driver.current_url
#       2 print("URL Extracted: ", url_string)
# ----> 3 lat_lng=re.findall(r'@(.*)data',url_string)
#
# NameError: name 're' is not defined

# %%
try:
    url_string=driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng=re.findall(r'@(.*)data',url_string)
# Out:
#   File "C:\Users\Lalit Sharnagat\AppData\Local\Temp\ipykernel_24960\2962743998.py", line 4
#     lat_lng=re.findall(r'@(.*)data',url_string)
#                                                ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # Question No:-6

# %%
driver.get('https://www.digit.in')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[4]/ul/li[4]")
search.click()

# %%
laptopsearch=driver.find_element(By.XPATH,"/html/body/div[7]/div/div/div[2]/div[5]/div[1]/div/button[2]")
laptopsearch.click()

# %%
gaming=driver.find_element(By.XPATH,"/html/body/div[7]/div/div/div[2]/div[5]/div[3]/div[2]/a/div[2]/p")
gaming.click()

# %%
Brand_Name=[]
Operating_system=[]
Display_size=[]
Processor_title=[]
Memory_title=[]
Graphics_processor=[]
Body_title=[]
Price_title=[]

# %%
brand=driver.find_elements(By.XPATH,'//div[@class="left_side"]/a/h3')
for i in brand:
    Brand=i.text
    Brand_Name.append(Brand)
    
operating=driver.find_elements(By.XPATH,'//div[@class="Specs-Wrap"]/ul/li[1]/div/div')
for i in operating:
    Operating=i.text
    Operating_system.append(Operating)
    
    
display=driver.find_elements(By.XPATH,'//div[@class="Specs-Wrap"]/ul/li[2]/div/div')
for i in display:
    Display=i.text
    Display_size.append(Display)

processor=driver.find_elements(By.XPATH,'//div[@class="Specs-Wrap"]/ul/li[4]/div/div')
for i in processor:
    Processor=i.text
    Processor_title.append(Processor)

memory=driver.find_elements(By.XPATH,'//div[@class="Specs-Wrap"]/ul/li[5]/div/div')
for i in memory:
    Memory=i.text
    Memory_title.append(Memory)    
    
graphics=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
for i in graphics:
    Graphics=i.text
    Graphics_processor.append(Graphics)
    
body=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
for i in body :
    Body=i.text
    Body_title.append(Body)
    
Price=driver.find_elements(By.XPATH,'//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for i in Price :
    Price=i.text
    Price_title.append(Price)

# %%
print(len(Brand_Name),len(Operating_system),len(Display_size),len(Processor_title),len(Memory_title),len(Graphics_processor),len(Body_title),len(Price_title))
# Out:
# 9 9 9 9 9 9 9 9

# %%
import pandas as pd
df=pd.DataFrame({'Brand Name':Brand_Name,'Operating_system':Operating_system,'Display size':Display_size,'Processor':Processor_title,'Memory':Memory_title,'Graphics processor':Graphics_processor,'Body size':Body_title,'Price':Price_title})
df
# Out:
#                           Brand Name    Operating_system  \
# 0                   Dell XPS 13 9320  Windows 11 Home OS
# 1        Realme Book (Slim) RMNB1001  Windows 10 Home OS
# 2        HP Spectre X360 13-Aw2001TU  Windows 10 Home OS
# 3  Lenovo Yoga Slim 7 Pro 82NC00EWIN  Windows 11 Home OS
# 4            Fujitsu UH-X 4ZR1F38024  Windows 11 Home OS
# 5           Xiaomi NoteBook Pro 120G       Windows 11 OS
# 6       HP Pavilion Aero 13-Be0208AU  Windows 11 Home OS
# 7         Microsoft Surface Laptop 3  Windows 10 Home OS
# 8                  MI Notebook Ultra  Windows 11 Home OS
#
#                   Display size  \
# 0  13.4" (3840 x 2400) Display
# 1    14" (2160 x 1440) Display
# 2  13.5" (1920 x 1280) Display
# 3    14" (2880 x 1800) Display
# 4  13.3" (1920 x 1080) Display
# 5    14" (2560 x 1600) Display
# 6  13.3" (1920 x 1200) Display
# 7    15" (2496 x 1664) Display
# 8  15.6" (3200 x 2000) Display
#
#                                            Processor  \
# ...

# %%
driver.get('https://www.hostelworld.com')

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[1]/div/div/div/input")
search.send_keys("London ")

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[1]/div/div/ul/li[2]")
search.click()

# %%
search=driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div/div/div[4]/div/div[2]/div/div[5]/button")
search.click()

# %%
product_url=[] 
url=driver.find_elements(By.XPATH,'//a[@class="view-button"]')
for i in url:
    product_url.append(i.get_attribute('href'))
    print(i.get_attribute('href'))
    time.sleep(3)
# Out:
# https://www.hostelworld.com/pwa/hosteldetails.php/Wombat-s-City-Hostel-London/London/88047?from=2023-03-19&to=2023-03-22&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2023-03-19&to=2023-03-22&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Hostel-One-Notting-Hill/London/291433?from=2023-03-19&to=2023-03-22&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Generator-London/London/510?from=2023-03-19&to=2023-03-22&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/NX-London-Hostel/London/15204?from=2023-03-19&to=2023-03-22&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Pickwick-Hall/London/7502?from=2023-03-19&to=2023-03-22&guests=2
# https://www.hostelworld.com/pwa/hosteldetails.php/Safestay-London-Elephant-Castle/London/55551?from=2023-03-19&to=2023-03-22&guests=2
# ...

# %%
print(len(product_url))
# Out:
# 30

# %%
Privates_from_price=[]
Hostel_Name=[]

# %%
for url in product_url[0:10]:
    driver.get(url)
    time.sleep(5)
    
    try:
        Hostel_name=driver.find_element(By.XPATH,'//h2[@class="title title-6"]')
        Hostel_Name.append(Hostel_name.text)
    except NoSuchElementException:
        Hostel_Name.append('-')

# %%
print(Hostel_Name)
# Out:
# ['-', '-', '-', '-', '-', '-', '-', '-', '-', '-']

# %%
try:
    Hostel_name=driver.find_element(By.XPATH,'//h2[@class="title title-6"]')
    Hostel_Name.append(Hostel_name.text)
except NoSuchElementException:
    Hostel_Name.append('-') 
    
try:
    privates_from_price=driver.find_element(By.X

# %%
distance=driver.find_elements(By.XPATH,'//span[@class="description"]')
for i in distance:
    Distance =i.text
    Distance_from_city_centre.append(Distance)
    
ratings=driver.find_elements(By.XPATH,'//div[@class="score orange big"]')
for i in  ratings:
    Ratings=i.text
    Ratings_title.append(Ratings)

total=driver.find_elements(By.XPATH,'//div[@class="reviews"]')
for i in  total:
    Total=i.text
    Total_reviews.append(Total)
    
privates=driver.find_elements(By.XPATH,'//div[@class="prices-col"]/a[1]/div[1]/div')
for i in privates:
    Privates=i.text
    Privates_from_price.append(Privates.split('|')[0])

# %%
print(len(Privates_from_price))
# Out:
# 43
